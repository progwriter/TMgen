# %%
from tmgen.models import *

# This is optional for vizualization only
# %matplotlib inline

# %%
tm = random_gravity_tm(200, 1)

# %%
print(tm.matrix.sum().sum())
# Out:
# 1.0

# %%
print (tm.matrix.shape)
# Out:
# (200, 200, 1)

# %%
import pickle
print (pickle.dumps(tm.matrix, protocol=pickle.HIGHEST_PROTOCOL))
# Out:
# b'\x80\x04\x95\x97\xe2\x04\x00\x00\x00\x00\x00\x8c\x15numpy.core.multiarray\x94\x8c\x0c_reconstruct\x94\x93\x94\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94K\x00\x85\x94C\x01b\x94\x87\x94R\x94(K\x01K\xc8K\xc8K\x01\x87\x94\x8c\x05numpy\x94\x8c\x05dtype\x94\x93\x94\x8c\x02f8\x94K\x00K\x01\x87\x94R\x94(K\x03\x8c\x01<\x94NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00t\x94b\x89B\x00\xe2\x04\x00u\x9a,\xc0\x94\xf7\xfe>\xa0\xb6D\x03\x02\x8a\xfd>\x94\xb84{\xbb\xce\t?9_b\n\xa1\\\x07?\x9e.W|\xc1\xe2\x03?\x9d\xbf\x93P\xf9\x0e\x05?)\x80\x14\xd5$\xce\t?\xa4\xc1a\x0cZ\x98\x02?\xff\x7f\xeeQ\xc6\x8d\xfb>\xd1\x9f\xd4,\xad\xca\xfd>\xd5\x8dg\xb4\x0b\xa7\x05?\xd0\xa1if\xbd~\x07?w\xc1PH\xeb\r\xfa>Q@6\x12\xf0o\xec>\xef\xddD\xc5\xfa`\xfc>W\x0b\xfa\x93\ty\x08?|\xbb\xa1\xa1\xc2\xf6\xf2>\x85\x84\xe5\t\xf9\xcc\xf4>\xb3\xcc\xd7Z-\x06\xc9>\xe0\'\xed,z \x02?\xef?\xb8>\xaa\x16\xe4>_-\x81\xb3HO\xdb>R\xdco\x03\x83\xda\xfd>\xef\xbf\xbfw\xd0\x8b\xf0>1\tN\x92\xea\xe2\xdf>\xf0 \xbe\xe1%h\xfd>\xd5\xb6dl\xcd\x9f\xf9>\x0b7M?.\xa
# ...
